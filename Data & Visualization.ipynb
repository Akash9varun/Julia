# %% [markdown]
# # Working with real world files - csv files

# %%
using CSV
using DataFrames

# %%
df = CSV.read("/Users/akashvarun/Development/JULIA101/iris.csv",DataFrame)
# Out:
# 150×6 DataFrame. Omitted printing of 1 columns
# │ Row │ Column1 │ Sepal.Length │ Sepal.Width │ Petal.Length │ Petal.Width │
# │     │ Int64   │ Float64      │ Float64     │ Float64      │ Float64     │
# ├─────┼─────────┼──────────────┼─────────────┼──────────────┼─────────────┤
# │ 1   │ 1       │ 5.1          │ 3.5         │ 1.4          │ 0.2         │
# │ 2   │ 2       │ 4.9          │ 3.0         │ 1.4          │ 0.2         │
# │ 3   │ 3       │ 4.7          │ 3.2         │ 1.3          │ 0.2         │
# │ 4   │ 4       │ 4.6          │ 3.1         │ 1.5          │ 0.2         │
# │ 5   │ 5       │ 5.0          │ 3.6         │ 1.4          │ 0.2         │
# │ 6   │ 6       │ 5.4          │ 3.9         │ 1.7          │ 0.4         │
# │ 7   │ 7       │ 4.6          │ 3.4         │ 1.4          │ 0.3         │
# │ 8   │ 8       │ 5.0          │ 3.4         │ 1.5          │ 0.2         │
# │ 9   │ 9       │ 4.4          │ 2.9         │ 1.4          │ 0.2         │
# ...

# %%
df = CSV.read("/Users/akashvarun/Development/JULIA101/iris.csv",DataFrame,normalizenames = true)
# Out:
# 150×6 DataFrame. Omitted printing of 1 columns
# │ Row │ Column1 │ Sepal_Length │ Sepal_Width │ Petal_Length │ Petal_Width │
# │     │ Int64   │ Float64      │ Float64     │ Float64      │ Float64     │
# ├─────┼─────────┼──────────────┼─────────────┼──────────────┼─────────────┤
# │ 1   │ 1       │ 5.1          │ 3.5         │ 1.4          │ 0.2         │
# │ 2   │ 2       │ 4.9          │ 3.0         │ 1.4          │ 0.2         │
# │ 3   │ 3       │ 4.7          │ 3.2         │ 1.3          │ 0.2         │
# │ 4   │ 4       │ 4.6          │ 3.1         │ 1.5          │ 0.2         │
# │ 5   │ 5       │ 5.0          │ 3.6         │ 1.4          │ 0.2         │
# │ 6   │ 6       │ 5.4          │ 3.9         │ 1.7          │ 0.4         │
# │ 7   │ 7       │ 4.6          │ 3.4         │ 1.4          │ 0.3         │
# │ 8   │ 8       │ 5.0          │ 3.4         │ 1.5          │ 0.2         │
# │ 9   │ 9       │ 4.4          │ 2.9         │ 1.4          │ 0.2         │
# ...

# %%
typeof(df)
# Out:
# DataFrame

# %%
names(df)
# Out:
# 6-element Vector{String}:
#  "Column1"
#  "Sepal_Length"
#  "Sepal_Width"
#  "Petal_Length"
#  "Petal_Width"
#  "Species"

# %%
size(df)
# Out:
# (150, 6)

# %%
head(df)
# Out:
# 6×6 DataFrame. Omitted printing of 1 columns
# │ Row │ Column1 │ Sepal_Length │ Sepal_Width │ Petal_Length │ Petal_Width │
# │     │ Int64   │ Float64      │ Float64     │ Float64      │ Float64     │
# ├─────┼─────────┼──────────────┼─────────────┼──────────────┼─────────────┤
# │ 1   │ 1       │ 5.1          │ 3.5         │ 1.4          │ 0.2         │
# │ 2   │ 2       │ 4.9          │ 3.0         │ 1.4          │ 0.2         │
# │ 3   │ 3       │ 4.7          │ 3.2         │ 1.3          │ 0.2         │
# │ 4   │ 4       │ 4.6          │ 3.1         │ 1.5          │ 0.2         │
# │ 5   │ 5       │ 5.0          │ 3.6         │ 1.4          │ 0.2         │
# │ 6   │ 6       │ 5.4          │ 3.9         │ 1.7          │ 0.4         │

# %%
iris = select(df, [:Sepal_Length,:Sepal_Width,:Petal_Length,:Petal_Width,:Species])
# Out:
# 150×5 DataFrame
# │ Row │ Sepal_Length │ Sepal_Width │ Petal_Length │ Petal_Width │ Species   │
# │     │ Float64      │ Float64     │ Float64      │ Float64     │ String    │
# ├─────┼──────────────┼─────────────┼──────────────┼─────────────┼───────────┤
# │ 1   │ 5.1          │ 3.5         │ 1.4          │ 0.2         │ setosa    │
# │ 2   │ 4.9          │ 3.0         │ 1.4          │ 0.2         │ setosa    │
# │ 3   │ 4.7          │ 3.2         │ 1.3          │ 0.2         │ setosa    │
# │ 4   │ 4.6          │ 3.1         │ 1.5          │ 0.2         │ setosa    │
# │ 5   │ 5.0          │ 3.6         │ 1.4          │ 0.2         │ setosa    │
# │ 6   │ 5.4          │ 3.9         │ 1.7          │ 0.4         │ setosa    │
# │ 7   │ 4.6          │ 3.4         │ 1.4          │ 0.3         │ setosa    │
# │ 8   │ 5.0          │ 3.4         │ 1.5          │ 0.2         │ setosa    │
# │ 9   │ 4.4          │ 2.9         │ 1.4          │ 0.2         │ setosa    │
# ...

# %%
#delete!(df, :B) you can this funcation more effective

# %%
typeof(iris)
# Out:
# DataFrame

# %%
size(iris)
# Out:
# (150, 5)

# %%
head(iris)
# Out:
# 6×5 DataFrame
# │ Row │ Sepal_Length │ Sepal_Width │ Petal_Length │ Petal_Width │ Species │
# │     │ Float64      │ Float64     │ Float64      │ Float64     │ String  │
# ├─────┼──────────────┼─────────────┼──────────────┼─────────────┼─────────┤
# │ 1   │ 5.1          │ 3.5         │ 1.4          │ 0.2         │ setosa  │
# │ 2   │ 4.9          │ 3.0         │ 1.4          │ 0.2         │ setosa  │
# │ 3   │ 4.7          │ 3.2         │ 1.3          │ 0.2         │ setosa  │
# │ 4   │ 4.6          │ 3.1         │ 1.5          │ 0.2         │ setosa  │
# │ 5   │ 5.0          │ 3.6         │ 1.4          │ 0.2         │ setosa  │
# │ 6   │ 5.4          │ 3.9         │ 1.7          │ 0.4         │ setosa  │

# %%
tail(iris,10)
# Out:
# 10×5 DataFrame
# │ Row │ Sepal_Length │ Sepal_Width │ Petal_Length │ Petal_Width │ Species   │
# │     │ Float64      │ Float64     │ Float64      │ Float64     │ String    │
# ├─────┼──────────────┼─────────────┼──────────────┼─────────────┼───────────┤
# │ 1   │ 6.7          │ 3.1         │ 5.6          │ 2.4         │ virginica │
# │ 2   │ 6.9          │ 3.1         │ 5.1          │ 2.3         │ virginica │
# │ 3   │ 5.8          │ 2.7         │ 5.1          │ 1.9         │ virginica │
# │ 4   │ 6.8          │ 3.2         │ 5.9          │ 2.3         │ virginica │
# │ 5   │ 6.7          │ 3.3         │ 5.7          │ 2.5         │ virginica │
# │ 6   │ 6.7          │ 3.0         │ 5.2          │ 2.3         │ virginica │
# │ 7   │ 6.3          │ 2.5         │ 5.0          │ 1.9         │ virginica │
# │ 8   │ 6.5          │ 3.0         │ 5.2          │ 2.0         │ virginica │
# │ 9   │ 6.2          │ 3.4         │ 5.4          │ 2.3         │ virginica │
# ...

# %%
describe(iris)
# Out:
# 5×8 DataFrame. Omitted printing of 2 columns
# │ Row │ variable     │ mean    │ min    │ median │ max       │ nunique │
# │     │ Symbol       │ Union…  │ Any    │ Union… │ Any       │ Union…  │
# ├─────┼──────────────┼─────────┼────────┼────────┼───────────┼─────────┤
# │ 1   │ Sepal_Length │ 5.84333 │ 4.3    │ 5.8    │ 7.9       │         │
# │ 2   │ Sepal_Width  │ 3.05733 │ 2.0    │ 3.0    │ 4.4       │         │
# │ 3   │ Petal_Length │ 3.758   │ 1.0    │ 4.35   │ 6.9       │         │
# │ 4   │ Petal_Width  │ 1.19933 │ 0.1    │ 1.3    │ 2.5       │         │
# │ 5   │ Species      │         │ setosa │        │ virginica │ 3       │

# %%
iris.Species
# Out:
# 150-element PooledArrays.PooledVector{String, UInt32, Vector{UInt32}}:
#  "setosa"
#  "setosa"
#  "setosa"
#  "setosa"
#  "setosa"
#  "setosa"
#  "setosa"
#  "setosa"
#  "setosa"
#  "setosa"
#  "setosa"
#  "setosa"
#  "setosa"
#  ⋮
#  "virginica"
#  "virginica"
#  "virginica"
#  "virginica"
#  "virginica"
#  "virginica"
#  "virginica"
#  "virginica"
#  "virginica"
#  "virginica"
#  "virginica"
#  "virginica"

# %%
iris.Petal_Length
# Out:
# 150-element Vector{Float64}:
#  1.4
#  1.4
#  1.3
#  1.5
#  1.4
#  1.7
#  1.4
#  1.5
#  1.4
#  1.5
#  1.5
#  1.6
#  1.4
#  ⋮
#  4.8
#  5.4
#  5.6
#  5.1
#  5.1
#  5.9
#  5.7
#  5.2
#  5.0
#  5.2
#  5.4
#  5.1

# %%
iris[:,3] #printing values of 3rd column
# Out:
# 150-element Vector{Float64}:
#  1.4
#  1.4
#  1.3
#  1.5
#  1.4
#  1.7
#  1.4
#  1.5
#  1.4
#  1.5
#  1.5
#  1.6
#  1.4
#  ⋮
#  4.8
#  5.4
#  5.6
#  5.1
#  5.1
#  5.9
#  5.7
#  5.2
#  5.0
#  5.2
#  5.4
#  5.1

# %%
iris[:,[1,2,3]]#print 1,2,3 columns
# Out:
# 150×3 DataFrame
# │ Row │ Sepal_Length │ Sepal_Width │ Petal_Length │
# │     │ Float64      │ Float64     │ Float64      │
# ├─────┼──────────────┼─────────────┼──────────────┤
# │ 1   │ 5.1          │ 3.5         │ 1.4          │
# │ 2   │ 4.9          │ 3.0         │ 1.4          │
# │ 3   │ 4.7          │ 3.2         │ 1.3          │
# │ 4   │ 4.6          │ 3.1         │ 1.5          │
# │ 5   │ 5.0          │ 3.6         │ 1.4          │
# │ 6   │ 5.4          │ 3.9         │ 1.7          │
# │ 7   │ 4.6          │ 3.4         │ 1.4          │
# │ 8   │ 5.0          │ 3.4         │ 1.5          │
# │ 9   │ 4.4          │ 2.9         │ 1.4          │
# │ 10  │ 4.9          │ 3.1         │ 1.5          │
# ⋮
# │ 140 │ 6.9          │ 3.1         │ 5.4          │
# │ 141 │ 6.7          │ 3.1         │ 5.6          │
# │ 142 │ 6.9          │ 3.1         │ 5.1          │
# │ 143 │ 5.8          │ 2.7         │ 5.1          │
# │ 144 │ 6.8          │ 3.2         │ 5.9          │
# ...

# %%
iris[1:5,:] #printing 1st 5 columns and 5 rows
# Out:
# 5×5 DataFrame
# │ Row │ Sepal_Length │ Sepal_Width │ Petal_Length │ Petal_Width │ Species │
# │     │ Float64      │ Float64     │ Float64      │ Float64     │ String  │
# ├─────┼──────────────┼─────────────┼──────────────┼─────────────┼─────────┤
# │ 1   │ 5.1          │ 3.5         │ 1.4          │ 0.2         │ setosa  │
# │ 2   │ 4.9          │ 3.0         │ 1.4          │ 0.2         │ setosa  │
# │ 3   │ 4.7          │ 3.2         │ 1.3          │ 0.2         │ setosa  │
# │ 4   │ 4.6          │ 3.1         │ 1.5          │ 0.2         │ setosa  │
# │ 5   │ 5.0          │ 3.6         │ 1.4          │ 0.2         │ setosa  │

# %%
iris[1:5,1:2] # printing 1st rows and 2 columns
# Out:
# 5×2 DataFrame
# │ Row │ Sepal_Length │ Sepal_Width │
# │     │ Float64      │ Float64     │
# ├─────┼──────────────┼─────────────┤
# │ 1   │ 5.1          │ 3.5         │
# │ 2   │ 4.9          │ 3.0         │
# │ 3   │ 4.7          │ 3.2         │
# │ 4   │ 4.6          │ 3.1         │
# │ 5   │ 5.0          │ 3.6         │

# %% [markdown]
# # Visualization Data

# %%
#using Pkg
#ENV["GRDIR"]=""
#Pkg.build("GR")

# %%
using Plots
#using GR
#using StatsPlots

# %%
plot()

# %%
x = 1:15; y = rand(15)
# Out:
# 15-element Vector{Float64}:
#  0.5522940377396335
#  0.032516951996588106
#  0.18616509009844395
#  0.6358685915407698
#  0.9852743049145329
#  0.07830126262822634
#  0.5646709771314325
#  0.8888310657574325
#  0.4478246954303252
#  0.41923563355534454
#  0.25621443873823735
#  0.9979238048152771
#  0.6062530367565856
#  0.5821861479211122
#  0.9826174239771839

# %%
plot(x,y)

# %%
using CSV

# %%
using DataFrames

# %%
df = CSV.read("/Users/akashvarun/Development/JULIA101/iris.csv",DataFrame,normalizenames = true)
# Out:
# 150×6 DataFrame
#  Row │ Column1  Sepal_Length  Sepal_Width  Petal_Length  Petal_Width  Species  ⋯
#      │ Int64    Float64       Float64      Float64       Float64      String15 ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │       1           5.1          3.5           1.4          0.2  setosa   ⋯
#    2 │       2           4.9          3.0           1.4          0.2  setosa
#    3 │       3           4.7          3.2           1.3          0.2  setosa
#    4 │       4           4.6          3.1           1.5          0.2  setosa
#    5 │       5           5.0          3.6           1.4          0.2  setosa   ⋯
#    6 │       6           5.4          3.9           1.7          0.4  setosa
#    7 │       7           4.6          3.4           1.4          0.3  setosa
#    8 │       8           5.0          3.4           1.5          0.2  setosa
#    9 │       9           4.4          2.9           1.4          0.2  setosa   ⋯
# ...

# %%
iris = select(df, [:Sepal_Length,:Sepal_Width,:Petal_Length,:Petal_Width,:Species])
# Out:
# 150×5 DataFrame
#  Row │ Sepal_Length  Sepal_Width  Petal_Length  Petal_Width  Species
#      │ Float64       Float64      Float64       Float64      String15
# ─────┼─────────────────────────────────────────────────────────────────
#    1 │          5.1          3.5           1.4          0.2  setosa
#    2 │          4.9          3.0           1.4          0.2  setosa
#    3 │          4.7          3.2           1.3          0.2  setosa
#    4 │          4.6          3.1           1.5          0.2  setosa
#    5 │          5.0          3.6           1.4          0.2  setosa
#    6 │          5.4          3.9           1.7          0.4  setosa
#    7 │          4.6          3.4           1.4          0.3  setosa
#    8 │          5.0          3.4           1.5          0.2  setosa
#    9 │          4.4          2.9           1.4          0.2  setosa
#   10 │          4.9          3.1           1.5          0.1  setosa
# ...

# %%
typeof(iris)
# Out:
# DataFrame

# %%
size(iris)
# Out:
# (150, 5)

# %%
plot(iris.Sepal_Length)

# %%
bar(iris.Species,iris.Petal_Length)
